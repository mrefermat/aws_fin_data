# %%
from bs4 import BeautifulSoup
import requests
import re
import js2xml

# %%
soup = BeautifulSoup(requests.get("https://cib.societegenerale.com/fileadmin/indices_feeds/ti_screen/index.html").content, "html.parser")
script =soup.find("script", text=re.compile("Highcharts.Chart")).text
#script = soup.find("script", text=re.compile("precipchartcontainer")).text if you want precipitation data
parsed = js2xml.parse(script)
print( js2xml.pretty_print(parsed))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8d4ea2048b82> in <module>()
#       1 soup = BeautifulSoup(requests.get("https://cib.societegenerale.com/fileadmin/indices_feeds/ti_screen/index.html").content, "html.parser")
# ----> 2 script =soup.find("script", text=re.compile("Highcharts.Chart")).text
#       3 #script = soup.find("script", text=re.compile("precipchartcontainer")).text if you want precipitation data
#       4 parsed = js2xml.parse(script)
#       5 print( js2xml.pretty_print(parsed))
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <title>SG Trend Indicator Daily Report</title>
# <link href="img/favicon.ico" rel="shortcut icon" type="image/x-icon; charset=binary"/>
# <link href="img/favicon.ico" rel="icon" type="image/x-icon; charset=binary"/>
# <link href="css/ti_page_201803.css" rel="stylesheet" type="text/css"/>
# <link href="css/dataTables_201801.css" rel="stylesheet" type="text/css"/>
# <link href="css/fixedHeader.dataTables_201706.css" rel="stylesheet" type="text/css"/>
# <link href="css/featherlight.min.css" rel="stylesheet" type="text/css"/>
# <link href="css/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <link href="css/hopscotch-0.2.6.min.css" rel="stylesheet" type="text/css"/>
# <script src="js/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/jquery-ui.1.12.1.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/highstock.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/exporting.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/data.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/drilldown.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/d3.v4.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/jquery.dataTables.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/dataTables.rowGroup.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/dataTables.fixedHeader.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/featherlight.1.5.0.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/hopscotch-0.2.6.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/ti_dashboard_201801.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/ti_dashboard_tour_201706.js" type="text/javascript"></script>
# <script charset="utf-8" src="js/konami.js" type="text/javascript"></script>
# </head>
# <body>
# <div id="preloader"></div>
# <div id="header">
# <img alt="SG" id="logo" src="img/socGenLogo.png"/>
# <div align="right" id="banner"><h1>SG TREND INDICATOR</h1><br/><h2>SOCIETE GENERALE PRIME SERVICES</h2></div>
# <div id="info">
# <div id="company">
# <b>Alternative Investments Consulting<br/>
# 		Prime Services<br/></b>
# 		T (EU): +44 (0)20 7676 8225<br/>
# 		T (US): +1 212 278 7774
# 		</div>
# <div id="contacts">
# <b>Europe &amp; ME:</b> James Skeggs, Tom Wrobel, Alex Hill<br/>
# <b>Americas:</b> Alex Skorniakov, David Regan, Lianyan Liu<br/><br/>
# <a href="mailto:PRM.Consulting@sgcib.com">PRM.Consulting@sgcib.com</a>
# </div>
# <div align="right" id="trade_date">
# 			Trade Date:
# 			<input id="datepicker" onchange="window.location.href = 'index.html?tradeDate=' + this.value;" type="text"/>
# <div align="right" id="trade_date_message">(Select a date to view historical data)</div>
# </div>
# <div align="right" id="break">
# <button class="tour_button" id="startTourBtn">Take a tour</button>
# <div align="right" id="source">*Source for all data: SG Prime Services &amp; Bloomberg</div>
# </div>
# </div>
# </div>
# <div class="left-wrapper">
# <div id="summary">
# <table cellspacing="0" class="hover" id="summaryTable" width="100%">
# <thead>
# <tr>
# <th>Benchmark</th>
# <th>Daily</th>
# <th>Month to Date</th>
# <th>Year to Date</th>
# <td class="net" rowspan="5">(net of fees)</td>
# </tr>
# </thead>
# </table>
# <div class="source"></div>
# </div>
# <div id="perfStats">
# <div class="sectionTitle">Performance Statistics (since 2002/10)</div>
# </div>
# <div class="source"></div>
# <div id="sectorChart"></div>
# <div id="navChart"></div>
# <div id="correlation"></div>
# <div id="ppc"></div>
# <div id="tradeDurationDistrib"></div>
# </div>
# <div class="right-wrapper">
# <div align="right" id="marketTable">
# <table cellspacing="0" class="hover nowrap" id="marketDataTable" width="100%">
# <thead id="marketDataTableHead">
# <tr>
# <td colspan="5"></td>
# <td align="center" class="gross" colspan="3">(gross returns)</td>
# </tr>
# <tr>
# <th></th>
# <th></th>
# <th>Market</th>
# <th>Position</th>
# <th>Days in Position</th>
# <th>Daily</th>
# <th>Month to Date</th>
# <th>Year to Date</th>
# <th>Sector</th>
# </tr>
# </thead>
# </table>
# <div class="source"></div>
# </div>
# <div align="right" id="watchlist">
# <table cellspacing="0" class="hover" id="watchlistTable" width="100%">
# <thead>
# <tr>
# <td align="left" class="heading" colspan="8">Market Signal Watch List
# 						<span class="tooltip">?
# 							<span class="tooltiptext">Markets with highest probability of reversal/signal switch next trading day</span>
# </span>
# </td>
# </tr>
# <tr>
# <th></th>
# <th>Market</th>
# <th>Current Position</th>
# <th>Yesterday's Close</th>
# <th>20 Day Moving Average</th>
# <th>120 Day Moving Average</th>
# <th>Reversal Price</th>
# <th>Reversal Price Move</th>
# </tr>
# </thead>
# </table>
# <div class="source"></div>
# </div>
# <div align="right" id="trades">
# <table cellspacing="0" class="hover" id="tradesTable" width="100%">
# <thead>
# <tr>
# <th></th>
# <th>Sector</th>
# <th>Market</th>
# <th>Trade Date</th>
# <th>New Position</th>
# </tr>
# </thead>
# </table>
# <div class="clear"></div>
# <div class="source"></div>
# </div>
# <div align="right" id="disclaimer">
# 	This website is published by Societe Generale, click<a data-featherlight="iframe" href="disclaimer.html" target="_blank">here to view the Disclaimer</a>and<a href="https://cib.societegenerale.com/en/legal/" target="_blank">here to view the general website Terms &amp; Conditions</a>
# </div>
# </div>
# <script src="https://1060771.collect.igodigital.com/collect.js" type="text/javascript"></script>
# <script type="text/javascript">
# _etmc.push(["setOrgId", "1060771"]);
# _etmc.push(["trackPageView"]);
# </script>
# </body>
# </html>

# %%
script = soup.find("script", text=re.compile("Highcharts.Chart"))
# script = soup.find("script", text=re.compile("precipchartcontainer")).text if you want precipitation data
parsed = js2xml.parse(soup.text)
print js2xml.pretty_print(parsed)
# Out:
#   File "<string>", line unknown
# SyntaxError: Unexpected token (ID, u'Weather') at 1:24 between LexToken(ID,u'Belgium',1,16) and LexToken(ID,u'Averages',1,32)

# %%
soup.find("script", text=re.compile("Highcharts.Chart"))

# %%
soup = BeautifulSoup(requests.get("http://www.worldweatheronline.com/brussels-weather-averages/be.aspx").content, "html.parser")

# %%
script = soup.find(text=re.compile("precipchartcontainer"))

# %%
soup.find("script", text=re.compile("Highcharts.Chart"))

# %%
script

# %%
soup.
# Out:
# u'\n\n\n\r\n\tBrussels, Belgium Weather Averages | Monthly Average High and Low Temperature | Average Precipitation and Rainfall days | World Weather Online\r\n\n\n\n\n\n\n\n\r\n  (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\r\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\r\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\r\n  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\r\n\r\n  ga(\'create\', \'UA-10779684-1\', \'auto\');\r\n  ga(\'send\', \'pageview\');\r\n\r\n\n\r\n      var freestar = freestar || {};\r\n      freestar.hitTime = Date.now();\r\n      freestar.queue = freestar.queue || [];\r\n      freestar.config = freestar.config || {};\r\n      freestar.debug = window.location.search.indexOf(\'fsdebug\') === -1 ? false : true;\r\n\r\n      // Tag IDs set here, must match Tags served in the Body for proper setup\r\n      freestar.config.enabled_slots = [\r\n          "worldweatheronline_300x250_300x600_160x600_320x50_Sidebar_1",\r\n          "worldweatheronline_728x90_970x90_970x250_300x250_320x50_Mid",\r\n          "worldweatheronline_728x90_970x90_970x250_300x250_320x50_BTF",          \r\n          "worldweatheronline_728x90_970x90_970x250_320x50_320x100_ATF",\r\n          "worldweatheronline_300x250_300x600_160x600_320x50_Sidebar_2",\r\n          "worldweatheronline_300x250_300x600_160x600_320x50_Sidebar_3",\r\n          "worldweatheronline_300x250_300x600_160x600_320x50_Sidebar_4"\r\n      ];\r\n\r\n      !function (a, b) { var c = b.getElementsByTagName("script")[0], d = b.createElement("script"), e = "https://a.pub.network/worldweatheronline-com"; e += freestar.debug ? "/qa/pubfig.min.js" : "/pubfig.min.js", d.async = !0, d.src = e, c.parentNode.insertBefore(d, c) }(window, document);\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n    freestar.queue.push(function () { googletag.display(\'worldweatheronline_728x90_970x90_970x250_320x50_320x100_ATF\'); });\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHOME\nAPI\nMap\nWORLD\nVIDEOS\nHOLIDAY\n\n\n\n\n\n\n\r\n                                                    GB\r\n                                                    \n\n\n\n\u0639\u0631\u0628\u0649AUCA\u4e2d\u6587DEESFRGBJANZPTRUUS\n\n\n\n\n\n\n\n\n\n\n\n\r\n        Search\r\n    \n\n\n\n\n\n\xb0C \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nYou have not set any favorites yet. Find out more\n\n\n\n\nChange Weather Units\n\n\n\nTemperature\n\n\nCelsius (\xb0C)Fahrenheit (\xb0F)\n\n\n\n\nRain\n\n\nMillimeters (mm)Inches (In)\n\n\n\n\nWind Speed\n\n\nMiles per Hour (mph)Kilometres per Hour (Kph)Knots (Kt)Beaufort Wind ScaleMetres per second (m/s)\n\n\n\n\nPressure\n\n\nMillibars (mb)Inches (In)\n\n\n\n\nVisibility\n\n\nKilometer (km)Miles (mi)\n\n\n\n\nHeight\n\n\nMetres (m)Feet (Ft)\n\n\n\nUpdate\n\n\n\n\n\n\nHOME\nAPI\nABOUT\nPersonal Weather Stations\nWebsite T&C; \nPrivacy Policy \nContact Us\nFavourites\nWeather Blog\nHoliday Guides\nSports Weather\n\n\n\nPopular Destinations\n\nTenerife\nAlgarve\nBali\nBenidorm\nMajorca\nLanzarote\nIbiza\nGran Canaria\nFuerteventura\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\nWorld Weather\nBelgiumBrussels\n\n\n\n\n\n\n\r\n                                                        Brussels Monthly Climate Averages\r\n                                                    \n\r\n                                                        BE\r\n                                                        \r\n                                                    \n\n\n\n\nView on Map\n\xa0\nFeedback\n\n\n\n\n\n\n Sunrise: 05:31 AM Sunset: 09:53 PM Moonrise: 03:07 AM Moonset: 03:08 PM Phase: Waning Crescent  with 41 % illumination.\n\n\n\n\n\n\n\n\r\n                                                        Brussels Current weather report\n\nLocal Time: Fri 08th Jun 2:43 pm\n\n\n\n\nBrussels\nBeauvechain\nCharleroi\n\n\n\n\n\n\n23 \xb0cPatchy rain possibleWind: 7 mph from NNW Rain: 56 %Humidity: 69%Pressure:  ...
